# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl
import tensorflow as tf
from path import Path
import numpy as np

# %%
# import anime csv and create df
file_path = Path("./data/anime.csv")
anime_df = pd.read_csv(file_path)
anime_df.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1509622
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 3      9253                         Steins;Gate     tv   9.08    1252286
# 4     28851                      Koe no Katachi  movie   8.95    1398608
#
#             status  episodes  start_date    end_date        source  ...  \
# 0  finished_airing      64.0  2009-04-05  2010-07-04         manga  ...
# 1  finished_airing     148.0  2011-10-02  2014-09-24         manga  ...
# 2  finished_airing      10.0  2019-04-29  2019-07-01         manga  ...
# 3  finished_airing      24.0  2011-04-06  2011-09-14  visual_novel  ...
# 4  finished_airing       1.0  2016-09-17  2016-09-17         manga  ...
#
#                                            producers  \
# 0  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1   ['VAP', 'Nippon Television Network', 'Shueisha']
# 2  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 3  ['Frontier Works', 'Media Factory', 'Movic', '...
# 4  ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                               licensors  \
# 0  ['Funimation', 'Aniplex of America']
# 1                         ['VIZ Media']
# 2                        ['Funimation']
# 3                        ['Funimation']
# 4          ['Eleven Arts', 'NYAV Post']
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Hunters devote themselves to accomplishing haz...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Eccentric scientist Rintarou Okabe has a never...
# 4  As a wild youth, elementary school student Sho...
#
#                                           background  \
# 0                                                NaN
# 1                                                NaN
# 2  Shingeki no Kyojin adapts content from volumes...
# 3  Steins;Gate is based on 5pb. and Nitroplus' re...
# 4  Winner of the Excellence Award on the 20th Jap...
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/anime/1223/...
# 1  https://cdn.myanimelist.net/images/anime/1337/...
# 2  https://cdn.myanimelist.net/images/anime/1517/...
# 3  https://cdn.myanimelist.net/images/anime/5/731...
# 4  https://cdn.myanimelist.net/images/anime/1122/...
#
#                                                  url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1  https://myanimelist.net/anime/11061/Hunter_x_H...
# 2  https://myanimelist.net/anime/38524/Shingeki_n...
# 3     https://myanimelist.net/anime/9253/Steins_Gate
# 4  https://myanimelist.net/anime/28851/Koe_no_Kat...
#
#                                    trailer_url  \
# 0  https://www.youtube.com/watch?v=--IcmZkvL0Q
# 1  https://www.youtube.com/watch?v=D9iTQRB4XRk
# 2  https://www.youtube.com/watch?v=hKHepjfj5Tw
# 3  https://www.youtube.com/watch?v=27OZc-ku6is
# 4  https://www.youtube.com/watch?v=XBNWo25izJ8
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                   Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2   Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                       Steins;Gate                 STEINS;GATE
# 4                    A Silent Voice                         聲の形
#
#                                       title_synonyms
# 0  ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                     ['HxH (2011)']
# 2                                                 []
# 3                                                 []
# 4                             ['The Shape of Voice']
#
# [5 rows x 39 columns]

# %%
# inspect columns and dtypes
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24165 entries, 0 to 24164
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anime_id          24165 non-null  int64
#  1   title             24165 non-null  object
#  2   type              24092 non-null  object
#  3   score             14272 non-null  float64
#  4   scored_by         24165 non-null  int64
#  5   status            24165 non-null  object
#  6   episodes          23397 non-null  float64
#  7   start_date        21391 non-null  object
#  8   end_date          19912 non-null  object
#  9   source            20404 non-null  object
#  10  members           24165 non-null  int64
#  11  favorites         24165 non-null  int64
#  12  episode_duration  23302 non-null  object
#  13  total_duration    23002 non-null  object
#  14  rating            23148 non-null  object
#  15  sfw               24165 non-null  bool
#  16  approved          24165 non-null  bool
#  17  created_at        24165 non-null  object
#  18  updated_at        24165 non-null  object
#  19  start_year        17749 non-null  float64
#  20  start_season      17749 non-null  object
#  21  real_start_date   21391 non-null  object
#  22  real_end_date     19912 non-null  object
#  23  broadcast_day     3065 non-null   object
#  24  broadcast_time    2928 non-null   object
#  25  genres            24165 non-null  object
#  26  themes            24165 non-null  object
#  27  demographics      24165 non-null  object
#  28  studios           24165 non-null  object
#  29  producers         24165 non-null  object
#  30  licensors         24165 non-null  object
#  31  synopsis          20848 non-null  object
#  32  background        2342 non-null   object
#  33  main_picture      21378 non-null  object
#  34  url               24165 non-null  object
#  35  trailer_url       4362 non-null   object
#  36  title_english     9084 non-null   object
#  37  title_japanese    23911 non-null  object
#  38  title_synonyms    24165 non-null  object
# dtypes: bool(2), float64(3), int64(4), object(30)
# memory usage: 6.9+ MB

# %%
anime_df.shape
# Out:
# (24165, 39)

# %% [markdown]
# ## Initial Thoughts

# %%
# supervised ML analysis: score by type, status, len (# episodes), source, rating/sfw, year, season
# broadcast_day, broadcast_time, genres/themes, demographics

# analysis: most popular genres/themes, most successful studios/producers/licensors

# keep: 
# anime_id, type, score, scored_by, status, episodes, start_date, source, rating, sfw, start_season,
#  broadcast_day, broadcast_time, genres, themes, demographics, studios, producers, licensors

# get_dummies: 
# type, status, source, rating, sfw, start_season, broadcast_day, genres, themes, demographics, studios,
# producers, licensors

# to_datetime: 
# start_date, broadcast_time

# drop: 
# title, end_date, members, favorites, episode_duration, total_duration, approved, created_at, 
# updated_at, start_year, real_start_date, real_end_date, synopsis, background, main_picture, url, trailer_url, 
# title_english, title_japanese, title_synonyms

# %% [markdown]
# ## Preprocessing - Deal with Null Values

# %%
# set index to anime_id
anime_df.set_index("anime_id", inplace=True)
anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#                    status  episodes  start_date    end_date        source  \
# anime_id
# 5114      finished_airing      64.0  2009-04-05  2010-07-04         manga
# 11061     finished_airing     148.0  2011-10-02  2014-09-24         manga
# 38524     finished_airing      10.0  2019-04-29  2019-07-01         manga
# 9253      finished_airing      24.0  2011-04-06  2011-09-14  visual_novel
# 28851     finished_airing       1.0  2016-09-17  2016-09-17         manga
#
#           members  ...                                          producers  \
# anime_id           ...
# 5114      2932347  ...  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 11061     2418883  ...   ['VAP', 'Nippon Television Network', 'Shueisha']
# 38524     1881734  ...  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 9253      2269121  ...  ['Frontier Works', 'Media Factory', 'Movic', '...
# 28851     2001335  ...  ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                                      licensors  \
# anime_id
# 5114      ['Funimation', 'Aniplex of America']
# 11061                            ['VIZ Media']
# 38524                           ['Funimation']
# 9253                            ['Funimation']
# 28851             ['Eleven Arts', 'NYAV Post']
#
#                                                    synopsis  \
# anime_id
# 5114      After a horrific alchemy experiment goes wrong...
# 11061     Hunters devote themselves to accomplishing haz...
# 38524     Seeking to restore humanity's diminishing hope...
# 9253      Eccentric scientist Rintarou Okabe has a never...
# 28851     As a wild youth, elementary school student Sho...
#
#                                                  background  \
# anime_id
# 5114                                                    NaN
# 11061                                                   NaN
# 38524     Shingeki no Kyojin adapts content from volumes...
# 9253      Steins;Gate is based on 5pb. and Nitroplus' re...
# 28851     Winner of the Excellence Award on the 20th Jap...
#
#                                                main_picture  \
# anime_id
# 5114      https://cdn.myanimelist.net/images/anime/1223/...
# 11061     https://cdn.myanimelist.net/images/anime/1337/...
# 38524     https://cdn.myanimelist.net/images/anime/1517/...
# 9253      https://cdn.myanimelist.net/images/anime/5/731...
# 28851     https://cdn.myanimelist.net/images/anime/1122/...
#
#                                                         url  \
# anime_id
# 5114      https://myanimelist.net/anime/5114/Fullmetal_A...
# 11061     https://myanimelist.net/anime/11061/Hunter_x_H...
# 38524     https://myanimelist.net/anime/38524/Shingeki_n...
# 9253         https://myanimelist.net/anime/9253/Steins_Gate
# 28851     https://myanimelist.net/anime/28851/Koe_no_Kat...
#
#                                           trailer_url  \
# anime_id
# 5114      https://www.youtube.com/watch?v=--IcmZkvL0Q
# 11061     https://www.youtube.com/watch?v=D9iTQRB4XRk
# 38524     https://www.youtube.com/watch?v=hKHepjfj5Tw
# 9253      https://www.youtube.com/watch?v=27OZc-ku6is
# 28851     https://www.youtube.com/watch?v=XBNWo25izJ8
#
#                              title_english              title_japanese  \
# anime_id
# 5114      Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 11061                      Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 38524      Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 9253                           Steins;Gate                 STEINS;GATE
# 28851                       A Silent Voice                         聲の形
#
#                                              title_synonyms
# anime_id
# 5114      ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 11061                                        ['HxH (2011)']
# 38524                                                    []
# 9253                                                     []
# 28851                                ['The Shape of Voice']
#
# [5 rows x 38 columns]

# %%
# drop useless columns
anime_df.drop(columns = ['end_date', 'members', 'favorites', 'episode_duration', 'total_duration', 'approved',
                        'created_at', 'updated_at', 'start_year', 'real_start_date', 'real_end_date', 'synopsis', 'background', 'main_picture', 'url', 'trailer_url',
                        'title_english', 'title_japanese', 'title_synonyms'], inplace=True)
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24165 entries, 5114 to 52477
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           24165 non-null  object
#  1   type            24092 non-null  object
#  2   score           14272 non-null  float64
#  3   scored_by       24165 non-null  int64
#  4   status          24165 non-null  object
#  5   episodes        23397 non-null  float64
#  6   start_date      21391 non-null  object
#  7   source          20404 non-null  object
#  8   rating          23148 non-null  object
#  9   sfw             24165 non-null  bool
#  10  start_season    17749 non-null  object
#  11  broadcast_day   3065 non-null   object
#  12  broadcast_time  2928 non-null   object
#  13  genres          24165 non-null  object
#  14  themes          24165 non-null  object
#  15  demographics    24165 non-null  object
#  16  studios         24165 non-null  object
#  17  producers       24165 non-null  object
#  18  licensors       24165 non-null  object
# dtypes: bool(1), float64(2), int64(1), object(15)
# memory usage: 3.5+ MB

# %%
# find null values
for column in anime_df:
    print(f"{column} has {anime_df[column].isnull().sum()} null values")
# Out:
# title has 0 null values
# type has 73 null values
# score has 9893 null values
# scored_by has 0 null values
# status has 0 null values
# episodes has 768 null values
# start_date has 2774 null values
# source has 3761 null values
# rating has 1017 null values
# sfw has 0 null values
# start_season has 6416 null values
# broadcast_day has 21100 null values
# broadcast_time has 21237 null values
# genres has 0 null values
# themes has 0 null values
# demographics has 0 null values
# studios has 0 null values
# producers has 0 null values
# licensors has 0 null values

# %%
# drop null values in score column
anime_df.dropna(subset=['score'], inplace=True)
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14272 entries, 5114 to 30408
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           14272 non-null  object
#  1   type            14271 non-null  object
#  2   score           14272 non-null  float64
#  3   scored_by       14272 non-null  int64
#  4   status          14272 non-null  object
#  5   episodes        14178 non-null  float64
#  6   start_date      14261 non-null  object
#  7   source          12516 non-null  object
#  8   rating          14176 non-null  object
#  9   sfw             14272 non-null  bool
#  10  start_season    13561 non-null  object
#  11  broadcast_day   2742 non-null   object
#  12  broadcast_time  2672 non-null   object
#  13  genres          14272 non-null  object
#  14  themes          14272 non-null  object
#  15  demographics    14272 non-null  object
#  16  studios         14272 non-null  object
#  17  producers       14272 non-null  object
#  18  licensors       14272 non-null  object
# dtypes: bool(1), float64(2), int64(1), object(15)
# memory usage: 2.1+ MB

# %%
# find null values
for column in anime_df:
    print(f"{column} has {anime_df[column].isnull().sum()} null values")
# Out:
# title has 0 null values
# type has 1 null values
# score has 0 null values
# scored_by has 0 null values
# status has 0 null values
# episodes has 94 null values
# start_date has 11 null values
# source has 1756 null values
# rating has 96 null values
# sfw has 0 null values
# start_season has 711 null values
# broadcast_day has 11530 null values
# broadcast_time has 11600 null values
# genres has 0 null values
# themes has 0 null values
# demographics has 0 null values
# studios has 0 null values
# producers has 0 null values
# licensors has 0 null values

# %%
# broadcast_day and broadcast_time have a ton of null values, which means they won't work for analysis - remove
# drop broadcast_day and broadcast_time columns and view null values again
anime_df.drop(columns = ['broadcast_day', 'broadcast_time'], inplace=True)
for column in anime_df:
    print(f"{column} has {anime_df[column].isnull().sum()} null values")
# Out:
# title has 0 null values
# type has 1 null values
# score has 0 null values
# scored_by has 0 null values
# status has 0 null values
# episodes has 94 null values
# start_date has 11 null values
# source has 1756 null values
# rating has 96 null values
# sfw has 0 null values
# start_season has 711 null values
# genres has 0 null values
# themes has 0 null values
# demographics has 0 null values
# studios has 0 null values
# producers has 0 null values
# licensors has 0 null values

# %%
# still have a fair number of null values under source, check total number of rows to see if they can be removed while still having a good number
anime_df.shape
# Out:
# (14272, 17)

# %%
# drop remaining null values and confirm removed
anime_df.dropna(inplace=True)
for column in anime_df:
    print(f"{column} has {anime_df[column].isnull().sum()} null values")
# Out:
# title has 0 null values
# type has 0 null values
# score has 0 null values
# scored_by has 0 null values
# status has 0 null values
# episodes has 0 null values
# start_date has 0 null values
# source has 0 null values
# rating has 0 null values
# sfw has 0 null values
# start_season has 0 null values
# genres has 0 null values
# themes has 0 null values
# demographics has 0 null values
# studios has 0 null values
# producers has 0 null values
# licensors has 0 null values

# %% [markdown]
# ### Conclusion to Section

# %%
# supervised ML analysis: score by type, status, len (# episodes), source, rating/sfw, start_date, season, genres/themes, demographics

# analysis: most popular genres/themes, most successful studios/producers/licensors

# keep: 
# anime_id, type, score, scored_by, status, episodes, start_date, source, rating, sfw, start_season,
# genres, themes, demographics, studios, producers, licensors

# get_dummies: 
# type, status, source, rating, sfw, start_season, broadcast_day, genres, themes, demographics, studios,
# producers, licensors

# to_datetime: 
# start_date

# drop: 
# title, end_date, members, favorites, episode_duration, total_duration, approved, created_at, 
# updated_at, start_year, real_start_date, real_end_date, synopsis, background, main_picture, url, trailer_url, 
# title_english, title_japanese, title_synonyms, broadcast_day, broadcast_time

# %% [markdown]
# ## Preprocessing - Deal with Categories

# %% [markdown]
# ### Type

# %%
# type
anime_df['type'].value_counts()
# Out:
# tv         3798
# ova        2658
# special    1518
# movie      1511
# ona        1387
# music       951
# Name: type, dtype: int64

# %% [markdown]
# #### Remove music videos

# %%
anime_df['type'] != 'music'
# Out:
# anime_id
# 5114      True
# 11061     True
# 38524     True
# 9253      True
# 28851     True
#          ...
# 38066     True
# 35514    False
# 36113    False
# 37336     True
# 40361     True
# Name: type, Length: 11823, dtype: bool

# %%
types_anime_df = anime_df.loc[(anime_df['type'] != 'music')]
types_anime_df['type'] != 'music'
# Out:
# anime_id
# 5114     True
# 11061    True
# 38524    True
# 9253     True
# 28851    True
#          ...
# 42234    True
# 38771    True
# 38066    True
# 37336    True
# 40361    True
# Name: type, Length: 10872, dtype: bool

# %%
types_anime_df.shape
# Out:
# (10872, 17)

# %% [markdown]
# ### Source

# %%
# source
types_anime_df['source'].value_counts()
# Out:
# manga           3763
# original        2892
# visual_novel    1059
# light_novel      804
# game             756
# novel            468
# other            356
# 4_koma_manga     263
# web_manga        245
# book              73
# card_game         59
# mixed_media       48
# picture_book      42
# music             26
# web_novel         13
# radio              5
# Name: source, dtype: int64

# %% [markdown]
# #### Remove sources with counts under 100

# %%
# code from stackoverflow https://stackoverflow.com/questions/49735683/python-removing-rows-on-count-condition
source_anime_df = types_anime_df[types_anime_df.groupby('source').
                                source.transform('count')>100]
source_anime_df['source'].value_counts()
# Out:
# manga           3763
# original        2892
# visual_novel    1059
# light_novel      804
# game             756
# novel            468
# other            356
# 4_koma_manga     263
# web_manga        245
# Name: source, dtype: int64

# %%
source_anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#                    status  episodes  start_date        source rating   sfw  \
# anime_id
# 5114      finished_airing      64.0  2009-04-05         manga      r  True
# 11061     finished_airing     148.0  2011-10-02         manga  pg_13  True
# 38524     finished_airing      10.0  2019-04-29         manga      r  True
# 9253      finished_airing      24.0  2011-04-06  visual_novel  pg_13  True
# 28851     finished_airing       1.0  2016-09-17         manga  pg_13  True
#
#          start_season                                       genres  \
# anime_id
# 5114           spring  ['Action', 'Adventure', 'Drama', 'Fantasy']
# 11061            fall           ['Action', 'Adventure', 'Fantasy']
# 38524          spring                          ['Action', 'Drama']
# 9253           spring              ['Drama', 'Sci-Fi', 'Suspense']
# 28851          summer                                    ['Drama']
#
#                                     themes demographics              studios  \
# anime_id
# 5114                          ['Military']  ['Shounen']            ['Bones']
# 11061                                   []  ['Shounen']         ['Madhouse']
# 38524     ['Gore', 'Military', 'Survival']  ['Shounen']       ['Wit Studio']
# 9253      ['Psychological', 'Time Travel']           []        ['White Fox']
# 28851                 ['Romantic Subtext']  ['Shounen']  ['Kyoto Animation']
#
#                                                   producers  \
# anime_id
# 5114      ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 11061      ['VAP', 'Nippon Television Network', 'Shueisha']
# 38524     ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 9253      ['Frontier Works', 'Media Factory', 'Movic', '...
# 28851     ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                                      licensors
# anime_id
# 5114      ['Funimation', 'Aniplex of America']
# 11061                            ['VIZ Media']
# 38524                           ['Funimation']
# 9253                            ['Funimation']
# 28851             ['Eleven Arts', 'NYAV Post']

# %% [markdown]
# ### Status

# %%
source_anime_df['status'].value_counts()
# Out:
# finished_airing     10554
# currently_airing       52
# Name: status, dtype: int64

# %%
# most are finished airing, so this is not statistically relevant

# %%
source_anime_df.drop(columns = ['status'], inplace=True)
source_anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#           episodes  start_date        source rating   sfw start_season  \
# anime_id
# 5114          64.0  2009-04-05         manga      r  True       spring
# 11061        148.0  2011-10-02         manga  pg_13  True         fall
# 38524         10.0  2019-04-29         manga      r  True       spring
# 9253          24.0  2011-04-06  visual_novel  pg_13  True       spring
# 28851          1.0  2016-09-17         manga  pg_13  True       summer
#
#                                                genres  \
# anime_id
# 5114      ['Action', 'Adventure', 'Drama', 'Fantasy']
# 11061              ['Action', 'Adventure', 'Fantasy']
# 38524                             ['Action', 'Drama']
# 9253                  ['Drama', 'Sci-Fi', 'Suspense']
# 28851                                       ['Drama']
#
#                                     themes demographics              studios  \
# anime_id
# 5114                          ['Military']  ['Shounen']            ['Bones']
# 11061                                   []  ['Shounen']         ['Madhouse']
# 38524     ['Gore', 'Military', 'Survival']  ['Shounen']       ['Wit Studio']
# 9253      ['Psychological', 'Time Travel']           []        ['White Fox']
# 28851                 ['Romantic Subtext']  ['Shounen']  ['Kyoto Animation']
#
#                                                   producers  \
# anime_id
# 5114      ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 11061      ['VAP', 'Nippon Television Network', 'Shueisha']
# 38524     ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 9253      ['Frontier Works', 'Media Factory', 'Movic', '...
# 28851     ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                                      licensors
# anime_id
# 5114      ['Funimation', 'Aniplex of America']
# 11061                            ['VIZ Media']
# 38524                           ['Funimation']
# 9253                            ['Funimation']
# 28851             ['Eleven Arts', 'NYAV Post']

# %% [markdown]
# ### SFW

# %%
source_anime_df['sfw'].value_counts()
# Out:
# True     9323
# False    1283
# Name: sfw, dtype: int64

# %% [markdown]
# ### Themes, Genres, and other lists

# %%
# genres, themes, demographics, studios, producers, licensors are all lists

# %%
# Convert from strings into lists
# https://towardsdatascience.com/dealing-with-list-values-in-pandas-dataframes-a177e534f173

# %%
# Genres
source_anime_df['genres'] = source_anime_df['genres'].apply(eval)
source_anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#           episodes  start_date        source rating   sfw start_season  \
# anime_id
# 5114          64.0  2009-04-05         manga      r  True       spring
# 11061        148.0  2011-10-02         manga  pg_13  True         fall
# 38524         10.0  2019-04-29         manga      r  True       spring
# 9253          24.0  2011-04-06  visual_novel  pg_13  True       spring
# 28851          1.0  2016-09-17         manga  pg_13  True       summer
#
#                                        genres  \
# anime_id
# 5114      [Action, Adventure, Drama, Fantasy]
# 11061            [Action, Adventure, Fantasy]
# 38524                         [Action, Drama]
# 9253                [Drama, Sci-Fi, Suspense]
# 28851                                 [Drama]
#
#                                     themes demographics              studios  \
# anime_id
# 5114                          ['Military']  ['Shounen']            ['Bones']
# 11061                                   []  ['Shounen']         ['Madhouse']
# 38524     ['Gore', 'Military', 'Survival']  ['Shounen']       ['Wit Studio']
# 9253      ['Psychological', 'Time Travel']           []        ['White Fox']
# 28851                 ['Romantic Subtext']  ['Shounen']  ['Kyoto Animation']
#
#                                                   producers  \
# anime_id
# 5114      ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 11061      ['VAP', 'Nippon Television Network', 'Shueisha']
# 38524     ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 9253      ['Frontier Works', 'Media Factory', 'Movic', '...
# 28851     ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                                      licensors
# anime_id
# 5114      ['Funimation', 'Aniplex of America']
# 11061                            ['VIZ Media']
# 38524                           ['Funimation']
# 9253                            ['Funimation']
# 28851             ['Eleven Arts', 'NYAV Post']

# %%
# Themes
source_anime_df['themes'] = source_anime_df['themes'].apply(eval)
source_anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#           episodes  start_date        source rating   sfw start_season  \
# anime_id
# 5114          64.0  2009-04-05         manga      r  True       spring
# 11061        148.0  2011-10-02         manga  pg_13  True         fall
# 38524         10.0  2019-04-29         manga      r  True       spring
# 9253          24.0  2011-04-06  visual_novel  pg_13  True       spring
# 28851          1.0  2016-09-17         manga  pg_13  True       summer
#
#                                        genres                        themes  \
# anime_id
# 5114      [Action, Adventure, Drama, Fantasy]                    [Military]
# 11061            [Action, Adventure, Fantasy]                            []
# 38524                         [Action, Drama]    [Gore, Military, Survival]
# 9253                [Drama, Sci-Fi, Suspense]  [Psychological, Time Travel]
# 28851                                 [Drama]            [Romantic Subtext]
#
#          demographics              studios  \
# anime_id
# 5114      ['Shounen']            ['Bones']
# 11061     ['Shounen']         ['Madhouse']
# 38524     ['Shounen']       ['Wit Studio']
# 9253               []        ['White Fox']
# 28851     ['Shounen']  ['Kyoto Animation']
#
#                                                   producers  \
# anime_id
# 5114      ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 11061      ['VAP', 'Nippon Television Network', 'Shueisha']
# 38524     ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 9253      ['Frontier Works', 'Media Factory', 'Movic', '...
# 28851     ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                                      licensors
# anime_id
# 5114      ['Funimation', 'Aniplex of America']
# 11061                            ['VIZ Media']
# 38524                           ['Funimation']
# 9253                            ['Funimation']
# 28851             ['Eleven Arts', 'NYAV Post']

# %%
# Demographics
source_anime_df['demographics'] = source_anime_df['demographics'].apply(eval)
source_anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#           episodes  start_date        source rating   sfw start_season  \
# anime_id
# 5114          64.0  2009-04-05         manga      r  True       spring
# 11061        148.0  2011-10-02         manga  pg_13  True         fall
# 38524         10.0  2019-04-29         manga      r  True       spring
# 9253          24.0  2011-04-06  visual_novel  pg_13  True       spring
# 28851          1.0  2016-09-17         manga  pg_13  True       summer
#
#                                        genres                        themes  \
# anime_id
# 5114      [Action, Adventure, Drama, Fantasy]                    [Military]
# 11061            [Action, Adventure, Fantasy]                            []
# 38524                         [Action, Drama]    [Gore, Military, Survival]
# 9253                [Drama, Sci-Fi, Suspense]  [Psychological, Time Travel]
# 28851                                 [Drama]            [Romantic Subtext]
#
#          demographics              studios  \
# anime_id
# 5114        [Shounen]            ['Bones']
# 11061       [Shounen]         ['Madhouse']
# 38524       [Shounen]       ['Wit Studio']
# 9253               []        ['White Fox']
# 28851       [Shounen]  ['Kyoto Animation']
#
#                                                   producers  \
# anime_id
# 5114      ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 11061      ['VAP', 'Nippon Television Network', 'Shueisha']
# 38524     ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 9253      ['Frontier Works', 'Media Factory', 'Movic', '...
# 28851     ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                                      licensors
# anime_id
# 5114      ['Funimation', 'Aniplex of America']
# 11061                            ['VIZ Media']
# 38524                           ['Funimation']
# 9253                            ['Funimation']
# 28851             ['Eleven Arts', 'NYAV Post']

# %%
# Studios
source_anime_df['studios'] = source_anime_df['studios'].apply(eval)
source_anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#           episodes  start_date        source rating   sfw start_season  \
# anime_id
# 5114          64.0  2009-04-05         manga      r  True       spring
# 11061        148.0  2011-10-02         manga  pg_13  True         fall
# 38524         10.0  2019-04-29         manga      r  True       spring
# 9253          24.0  2011-04-06  visual_novel  pg_13  True       spring
# 28851          1.0  2016-09-17         manga  pg_13  True       summer
#
#                                        genres                        themes  \
# anime_id
# 5114      [Action, Adventure, Drama, Fantasy]                    [Military]
# 11061            [Action, Adventure, Fantasy]                            []
# 38524                         [Action, Drama]    [Gore, Military, Survival]
# 9253                [Drama, Sci-Fi, Suspense]  [Psychological, Time Travel]
# 28851                                 [Drama]            [Romantic Subtext]
#
#          demographics            studios  \
# anime_id
# 5114        [Shounen]            [Bones]
# 11061       [Shounen]         [Madhouse]
# 38524       [Shounen]       [Wit Studio]
# 9253               []        [White Fox]
# 28851       [Shounen]  [Kyoto Animation]
#
#                                                   producers  \
# anime_id
# 5114      ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 11061      ['VAP', 'Nippon Television Network', 'Shueisha']
# 38524     ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 9253      ['Frontier Works', 'Media Factory', 'Movic', '...
# 28851     ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                                      licensors
# anime_id
# 5114      ['Funimation', 'Aniplex of America']
# 11061                            ['VIZ Media']
# 38524                           ['Funimation']
# 9253                            ['Funimation']
# 28851             ['Eleven Arts', 'NYAV Post']

# %%
# Producers
source_anime_df['producers'] = source_anime_df['producers'].apply(eval)
source_anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#           episodes  start_date        source rating   sfw start_season  \
# anime_id
# 5114          64.0  2009-04-05         manga      r  True       spring
# 11061        148.0  2011-10-02         manga  pg_13  True         fall
# 38524         10.0  2019-04-29         manga      r  True       spring
# 9253          24.0  2011-04-06  visual_novel  pg_13  True       spring
# 28851          1.0  2016-09-17         manga  pg_13  True       summer
#
#                                        genres                        themes  \
# anime_id
# 5114      [Action, Adventure, Drama, Fantasy]                    [Military]
# 11061            [Action, Adventure, Fantasy]                            []
# 38524                         [Action, Drama]    [Gore, Military, Survival]
# 9253                [Drama, Sci-Fi, Suspense]  [Psychological, Time Travel]
# 28851                                 [Drama]            [Romantic Subtext]
#
#          demographics            studios  \
# anime_id
# 5114        [Shounen]            [Bones]
# 11061       [Shounen]         [Madhouse]
# 38524       [Shounen]       [Wit Studio]
# 9253               []        [White Fox]
# 28851       [Shounen]  [Kyoto Animation]
#
#                                                   producers  \
# anime_id
# 5114      [Aniplex, Square Enix, Mainichi Broadcasting S...
# 11061            [VAP, Nippon Television Network, Shueisha]
# 38524     [Production I.G, Dentsu, Mainichi Broadcasting...
# 9253      [Frontier Works, Media Factory, Movic, AT-X, K...
# 28851     [Shochiku, Pony Canyon, Kodansha, ABC Animatio...
#
#                                      licensors
# anime_id
# 5114      ['Funimation', 'Aniplex of America']
# 11061                            ['VIZ Media']
# 38524                           ['Funimation']
# 9253                            ['Funimation']
# 28851             ['Eleven Arts', 'NYAV Post']

# %%
# Licensors
source_anime_df['licensors'] = source_anime_df['licensors'].apply(eval)
source_anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#           episodes  start_date        source rating   sfw start_season  \
# anime_id
# 5114          64.0  2009-04-05         manga      r  True       spring
# 11061        148.0  2011-10-02         manga  pg_13  True         fall
# 38524         10.0  2019-04-29         manga      r  True       spring
# 9253          24.0  2011-04-06  visual_novel  pg_13  True       spring
# 28851          1.0  2016-09-17         manga  pg_13  True       summer
#
#                                        genres                        themes  \
# anime_id
# 5114      [Action, Adventure, Drama, Fantasy]                    [Military]
# 11061            [Action, Adventure, Fantasy]                            []
# 38524                         [Action, Drama]    [Gore, Military, Survival]
# 9253                [Drama, Sci-Fi, Suspense]  [Psychological, Time Travel]
# 28851                                 [Drama]            [Romantic Subtext]
#
#          demographics            studios  \
# anime_id
# 5114        [Shounen]            [Bones]
# 11061       [Shounen]         [Madhouse]
# 38524       [Shounen]       [Wit Studio]
# 9253               []        [White Fox]
# 28851       [Shounen]  [Kyoto Animation]
#
#                                                   producers  \
# anime_id
# 5114      [Aniplex, Square Enix, Mainichi Broadcasting S...
# 11061            [VAP, Nippon Television Network, Shueisha]
# 38524     [Production I.G, Dentsu, Mainichi Broadcasting...
# 9253      [Frontier Works, Media Factory, Movic, AT-X, K...
# 28851     [Shochiku, Pony Canyon, Kodansha, ABC Animatio...
#
#                                  licensors
# anime_id
# 5114      [Funimation, Aniplex of America]
# 11061                          [VIZ Media]
# 38524                         [Funimation]
# 9253                          [Funimation]
# 28851             [Eleven Arts, NYAV Post]

# %% [markdown]
# ### Combine Genres and Themes into Keywords Column

# %%
source_anime_df['keywords'] = (source_anime_df['genres'] + source_anime_df['themes'])
source_anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#           episodes  start_date        source rating   sfw start_season  \
# anime_id
# 5114          64.0  2009-04-05         manga      r  True       spring
# 11061        148.0  2011-10-02         manga  pg_13  True         fall
# 38524         10.0  2019-04-29         manga      r  True       spring
# 9253          24.0  2011-04-06  visual_novel  pg_13  True       spring
# 28851          1.0  2016-09-17         manga  pg_13  True       summer
#
#                                        genres                        themes  \
# anime_id
# 5114      [Action, Adventure, Drama, Fantasy]                    [Military]
# 11061            [Action, Adventure, Fantasy]                            []
# 38524                         [Action, Drama]    [Gore, Military, Survival]
# 9253                [Drama, Sci-Fi, Suspense]  [Psychological, Time Travel]
# 28851                                 [Drama]            [Romantic Subtext]
#
#          demographics            studios  \
# anime_id
# 5114        [Shounen]            [Bones]
# 11061       [Shounen]         [Madhouse]
# 38524       [Shounen]       [Wit Studio]
# 9253               []        [White Fox]
# 28851       [Shounen]  [Kyoto Animation]
#
#                                                   producers  \
# anime_id
# 5114      [Aniplex, Square Enix, Mainichi Broadcasting S...
# 11061            [VAP, Nippon Television Network, Shueisha]
# 38524     [Production I.G, Dentsu, Mainichi Broadcasting...
# 9253      [Frontier Works, Media Factory, Movic, AT-X, K...
# 28851     [Shochiku, Pony Canyon, Kodansha, ABC Animatio...
#
#                                  licensors  \
# anime_id
# 5114      [Funimation, Aniplex of America]
# 11061                          [VIZ Media]
# 38524                         [Funimation]
# 9253                          [Funimation]
# 28851             [Eleven Arts, NYAV Post]
#
#                                                    keywords
# anime_id
# 5114          [Action, Adventure, Drama, Fantasy, Military]
# 11061                          [Action, Adventure, Fantasy]
# 38524             [Action, Drama, Gore, Military, Survival]
# 9253      [Drama, Sci-Fi, Suspense, Psychological, Time ...
# 28851                             [Drama, Romantic Subtext]

# %%
keywords_anime_df = source_anime_df.drop(columns = ['genres', 'themes'])
keywords_anime_df.head()
# Out:
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#           episodes  start_date        source rating   sfw start_season  \
# anime_id
# 5114          64.0  2009-04-05         manga      r  True       spring
# 11061        148.0  2011-10-02         manga  pg_13  True         fall
# 38524         10.0  2019-04-29         manga      r  True       spring
# 9253          24.0  2011-04-06  visual_novel  pg_13  True       spring
# 28851          1.0  2016-09-17         manga  pg_13  True       summer
#
#          demographics            studios  \
# anime_id
# 5114        [Shounen]            [Bones]
# 11061       [Shounen]         [Madhouse]
# 38524       [Shounen]       [Wit Studio]
# 9253               []        [White Fox]
# 28851       [Shounen]  [Kyoto Animation]
#
#                                                   producers  \
# anime_id
# 5114      [Aniplex, Square Enix, Mainichi Broadcasting S...
# 11061            [VAP, Nippon Television Network, Shueisha]
# 38524     [Production I.G, Dentsu, Mainichi Broadcasting...
# 9253      [Frontier Works, Media Factory, Movic, AT-X, K...
# 28851     [Shochiku, Pony Canyon, Kodansha, ABC Animatio...
#
#                                  licensors  \
# anime_id
# 5114      [Funimation, Aniplex of America]
# 11061                          [VIZ Media]
# 38524                         [Funimation]
# 9253                          [Funimation]
# 28851             [Eleven Arts, NYAV Post]
#
#                                                    keywords
# anime_id
# 5114          [Action, Adventure, Drama, Fantasy, Military]
# 11061                          [Action, Adventure, Fantasy]
# 38524             [Action, Drama, Gore, Military, Survival]
# 9253      [Drama, Sci-Fi, Suspense, Psychological, Time ...
# 28851                             [Drama, Romantic Subtext]

# %%
keywords_anime_df['keywords'].head()
# Out:
# anime_id
# 5114         [Action, Adventure, Drama, Fantasy, Military]
# 11061                         [Action, Adventure, Fantasy]
# 38524            [Action, Drama, Gore, Military, Survival]
# 9253     [Drama, Sci-Fi, Suspense, Psychological, Time ...
# 28851                            [Drama, Romantic Subtext]
# Name: keywords, dtype: object

# %% [markdown]
# ### Use to_datetime on start_date

# %%
keywords_anime_df['start_date'] = pd.to_datetime(keywords_anime_df['start_date'])
print(keywords_anime_df.dtypes)
keywords_anime_df.head()
# Out:
# title                   object
# type                    object
# score                  float64
# scored_by                int64
# episodes               float64
# start_date      datetime64[ns]
# source                  object
# rating                  object
# sfw                       bool
# start_season            object
# demographics            object
# studios                 object
# producers               object
# licensors               object
# keywords                object
# dtype: object
#                                        title   type  score  scored_by  \
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 11061                 Hunter x Hunter (2011)     tv   9.04    1509622
# 38524     Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 9253                             Steins;Gate     tv   9.08    1252286
# 28851                         Koe no Katachi  movie   8.95    1398608
#
#           episodes start_date        source rating   sfw start_season  \
# anime_id
# 5114          64.0 2009-04-05         manga      r  True       spring
# 11061        148.0 2011-10-02         manga  pg_13  True         fall
# 38524         10.0 2019-04-29         manga      r  True       spring
# 9253          24.0 2011-04-06  visual_novel  pg_13  True       spring
# 28851          1.0 2016-09-17         manga  pg_13  True       summer
#
#          demographics            studios  \
# anime_id
# 5114        [Shounen]            [Bones]
# 11061       [Shounen]         [Madhouse]
# 38524       [Shounen]       [Wit Studio]
# 9253               []        [White Fox]
# 28851       [Shounen]  [Kyoto Animation]
#
#                                                   producers  \
# anime_id
# 5114      [Aniplex, Square Enix, Mainichi Broadcasting S...
# 11061            [VAP, Nippon Television Network, Shueisha]
# 38524     [Production I.G, Dentsu, Mainichi Broadcasting...
# 9253      [Frontier Works, Media Factory, Movic, AT-X, K...
# 28851     [Shochiku, Pony Canyon, Kodansha, ABC Animatio...
#
#                                  licensors  \
# anime_id
# 5114      [Funimation, Aniplex of America]
# 11061                          [VIZ Media]
# 38524                         [Funimation]
# 9253                          [Funimation]
# 28851             [Eleven Arts, NYAV Post]
#
#                                                    keywords
# anime_id
# 5114          [Action, Adventure, Drama, Fantasy, Military]
# 11061                          [Action, Adventure, Fantasy]
# 38524             [Action, Drama, Gore, Military, Survival]
# 9253      [Drama, Sci-Fi, Suspense, Psychological, Time ...
# 28851                             [Drama, Romantic Subtext]

# %% [markdown]
# ### Examine demographics further

# %%
keywords_anime_df['demographics'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []                 7221
# [Shounen]          1585
# [Seinen]            728
# [Shoujo]            551
# [Kids]              380
# [Josei]              93
# [Kids, Shounen]      25
# [Kids, Shoujo]       21
# [Kids, Seinen]        1
# [Josei, Shoujo]       1
# Name: demographics, dtype: int64

# %%
# 66% do not have demographics attributed to them. Delete this column? Alternative is to pull anime data from Wikipedia and compare, but I would expect MAL to be better data than Wikipedia.
# There may be some additional data to pull from Wikipedia like directors and networks - is that relevant?

# %% [markdown]
# ## Clean CSVs - Anime Titles

# %%
# create df that holds anime_id and title
anime_titles_df = keywords_anime_df.copy()
anime_titles_df = pd.DataFrame(anime_titles_df['title'], index=keywords_anime_df.index)
anime_titles_df.head()
# Out:
#                                        title
# anime_id
# 5114        Fullmetal Alchemist: Brotherhood
# 11061                 Hunter x Hunter (2011)
# 38524     Shingeki no Kyojin Season 3 Part 2
# 9253                             Steins;Gate
# 28851                         Koe no Katachi

# %%
# save anime_titles_df as csv
output_file_path = "./data/anime_titles.csv"
anime_titles_df.to_csv(output_file_path, index=True)

# %%
# drop anime_titles from df
clean_anime_df = keywords_anime_df.drop(columns = ["title"])
clean_anime_df.head()
# Out:
#            type  score  scored_by  episodes start_date        source rating  \
# anime_id
# 5114         tv   9.13    1871705      64.0 2009-04-05         manga      r
# 11061        tv   9.04    1509622     148.0 2011-10-02         manga  pg_13
# 38524        tv   9.07    1329500      10.0 2019-04-29         manga      r
# 9253         tv   9.08    1252286      24.0 2011-04-06  visual_novel  pg_13
# 28851     movie   8.95    1398608       1.0 2016-09-17         manga  pg_13
#
#            sfw start_season demographics            studios  \
# anime_id
# 5114      True       spring    [Shounen]            [Bones]
# 11061     True         fall    [Shounen]         [Madhouse]
# 38524     True       spring    [Shounen]       [Wit Studio]
# 9253      True       spring           []        [White Fox]
# 28851     True       summer    [Shounen]  [Kyoto Animation]
#
#                                                   producers  \
# anime_id
# 5114      [Aniplex, Square Enix, Mainichi Broadcasting S...
# 11061            [VAP, Nippon Television Network, Shueisha]
# 38524     [Production I.G, Dentsu, Mainichi Broadcasting...
# 9253      [Frontier Works, Media Factory, Movic, AT-X, K...
# 28851     [Shochiku, Pony Canyon, Kodansha, ABC Animatio...
#
#                                  licensors  \
# anime_id
# 5114      [Funimation, Aniplex of America]
# 11061                          [VIZ Media]
# 38524                         [Funimation]
# 9253                          [Funimation]
# 28851             [Eleven Arts, NYAV Post]
#
#                                                    keywords
# anime_id
# 5114          [Action, Adventure, Drama, Fantasy, Military]
# 11061                          [Action, Adventure, Fantasy]
# 38524             [Action, Drama, Gore, Military, Survival]
# 9253      [Drama, Sci-Fi, Suspense, Psychological, Time ...
# 28851                             [Drama, Romantic Subtext]

# %%
# save clean_anime_df as csv
output_file_path = "./data/clean_anime.csv"
clean_anime_df.to_csv(output_file_path, index=True)

# %% [markdown]
# ## Next Steps

# %%
# get_dummies: 
# type, status, source, rating, sfw, start_season, demographics, studios,
# producers, licensors, keywords

# %%
clean_anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10606 entries, 5114 to 40361
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          10606 non-null  object
#  1   score         10606 non-null  float64
#  2   scored_by     10606 non-null  int64
#  3   episodes      10606 non-null  float64
#  4   start_date    10606 non-null  datetime64[ns]
#  5   source        10606 non-null  object
#  6   rating        10606 non-null  object
#  7   sfw           10606 non-null  bool
#  8   start_season  10606 non-null  object
#  9   demographics  10606 non-null  object
#  10  studios       10606 non-null  object
#  11  producers     10606 non-null  object
#  12  licensors     10606 non-null  object
#  13  keywords      10606 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(1), object(9)
# memory usage: 1.1+ MB
